# %%
import pandas as pd
from prompt_toolkit.key_binding.bindings.named_commands import end_of_file
from urllib3 import request

path = r'D:\WorkFlow\data_python\竞品数据\蔚蓝每日双端数据.xlsx' # 主表，名字写死
origin_data = pd.read_excel(path,sheet_name = '蔚蓝每日双端数据',index_col = 0)
pd.set_option('display.width', 500)
print(origin_data.head())
# Out:
#             国家        统一名称                     统一 ID   平台      设备   下载量      收入
# 日期
# 2025-10-29  HK  蔚藍星球: 國王很忙  68d0ed4f23721398b4b9582f  iOS    iPad    33   11.86
# 2025-10-29  HK  蔚藍星球: 國王很忙  68d0ed4f23721398b4b9582f  iOS  iPhone  2289  972.43
# 2025-10-29  MO  蔚藍星球: 國王很忙  68d0ed4f23721398b4b9582f  iOS    iPad     2    0.00
# 2025-10-29  MO  蔚藍星球: 國王很忙  68d0ed4f23721398b4b9582f  iOS  iPhone   104    3.52
# 2025-10-29  TW  蔚藍星球: 國王很忙  68d0ed4f23721398b4b9582f  iOS    iPad   109   14.79

# %%
#检测csv的encoding
print(origin_data.shape)
# Out:
# (852, 7)

# %%
origin_data.loc[(origin_data['平台']== 'IOS')|(origin_data['设备'] == 'iPad')]
# Out:
#             国家               统一名称                     统一 ID   平台    设备  下载量      收入
# 日期
# 2025-10-29  HK         蔚藍星球: 國王很忙  68d0ed4f23721398b4b9582f  iOS  iPad   33   11.86
# 2025-10-29  MO         蔚藍星球: 國王很忙  68d0ed4f23721398b4b9582f  iOS  iPad    2    0.00
# 2025-10-29  TW         蔚藍星球: 國王很忙  68d0ed4f23721398b4b9582f  iOS  iPad  109   14.79
# 2025-10-30  HK         蔚藍星球: 國王很忙  68d0ed4f23721398b4b9582f  iOS  iPad   45  120.02
# 2025-10-30  MO         蔚藍星球: 國王很忙  68d0ed4f23721398b4b9582f  iOS  iPad    0    2.80
# ...         ..                ...                       ...  ...   ...  ...     ...
# 2026-01-30  MO  永远的蔚蓝星球-合成快攻 对战轻松  669df1f882bbdbdf9ca2565b  iOS  iPad    0   28.30
# 2026-01-30  TW  永远的蔚蓝星球-合成快攻 对战轻松  669df1f882bbdbdf9ca2565b  iOS  iPad   25  470.69
# 2026-01-31  HK  永远的蔚蓝星球-合成快攻 对战轻松  669df1f882bbdbdf9ca2565b  iOS  iPad   25   92.60
# 2026-01-31  MO  永远的蔚蓝星球-合成快攻 对战轻松  669df1f882bbdbdf9ca2565b  iOS  iPad    0   21.53
# ...

# %%
import os
# 找到这个文件，没有的话就创建一个txt文件
path = r'D:\WorkFlow\data_python\竞品数据\望庐山瀑布.txt' #指向txt文件
if not os.path.exists(path):
    with open(path,'w+',encoding='utf-8') as f:
        f.write("飞流直下三千尺\n疑是银河落九天")
f.close()

# 找到这个文件夹，没有的话就创建这个文件夹
path1 = os.path.dirname(path) #父目录
folder = os.path.join(path1,'古诗词')
if not os.path.exists(folder):
    os.makedirs(folder,exist_ok=True)

print(f"path1:{path1}\nfolder:{folder}")
# Out:
# path1:D:\WorkFlow\data_python\竞品数据
# folder:D:\WorkFlow\data_python\竞品数据\古诗词

# %%
os.path.isdir(path)
if not os.path.exists(path):
    with open(path,'w+',encoding='utf-8') as f:
        f.write("日照香炉生紫烟\n遥看瀑布挂前川\n飞流直下三千尺\n疑是银河落九天")
f.close()

# %%
os.path.isdir(path)
# Out:
# False

# %%
f = open('望庐山瀑布.txt','r',encoding='utf-8')
print(f.readlines())
f.close()
# Out:
# ['飞流直下三千尺\n', '疑是银河落九天']

# %%
import requests
target_url = "https://www.tiobe.com/tiobe-index/"
response = requests.get(target_url)
print(response)
# Out:
# <Response [200]>

# %%
response.text
# Out:
# '\n<!DOCTYPE html>\n<html lang="en-US">\n\n<head>\n    <meta charset="UTF-8" />\n    <meta name="viewport" content="width=device-width, initial-scale=1.0" />\n        \t<title>TIOBE Index - TIOBE</title>\n\t    <link rel="profile" href="http://gmpg.org/xfn/11" />\n    <link rel="stylesheet" href="https://www.tiobe.com/wp-content/themes/tiobe/style.css" type="text/css" media="screen" />\n    <link rel="pingback" href="https://www.tiobe.com/xmlrpc.php" />\n\n    <link rel="apple-touch-icon" sizes="180x180" href="https://www.tiobe.com/wp-content/themes/tiobe/favicon/apple-touch-icon.png">\n    <link rel="icon" type="image/png" sizes="32x32" href="https://www.tiobe.com/wp-content/themes/tiobe/favicon/favicon-32x32.png">\n    <link rel="icon" type="image/png" sizes="16x16" href="https://www.tiobe.com/wp-content/themes/tiobe/favicon/favicon-16x16.png">\n    <link rel="manifest" href="https://www.tiobe.com/wp-content/themes/tiobe/favicon/site.webmanifest">\n    <link rel="mask-icon" href="h
# ...
